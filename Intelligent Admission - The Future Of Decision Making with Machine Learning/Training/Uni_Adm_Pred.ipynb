# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Admission.csv")

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  \
# 0           1        337          118                  4  4.5
# 1           2        324          107                  4  4.0
# 2           3        316          104                  3  3.0
# 3           4        322          110                  3  3.5
# 4           5        314          103                  2  2.0
#
#    Letter Of Recommendation  CGPA  Research   COA
# 0                       4.5  9.65         1  0.92
# 1                       4.5  8.87         1  0.76
# 2                       3.5  8.00         1  0.72
# 3                       2.5  8.67         1  0.80
# 4                       3.0  8.21         0  0.65

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Serial No.                400 non-null    int64
#  1   GRE Score                 400 non-null    int64
#  2   TOEFL Score               400 non-null    int64
#  3   University Rating         400 non-null    int64
#  4   SOP                       400 non-null    float64
#  5   Letter Of Recommendation  400 non-null    float64
#  6   CGPA                      400 non-null    float64
#  7   Research                  400 non-null    int64
#  8   COA                       400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
data.isnull()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating    SOP  \
# 0         False      False        False              False  False
# 1         False      False        False              False  False
# 2         False      False        False              False  False
# 3         False      False        False              False  False
# 4         False      False        False              False  False
# ..          ...        ...          ...                ...    ...
# 395       False      False        False              False  False
# 396       False      False        False              False  False
# 397       False      False        False              False  False
# 398       False      False        False              False  False
# 399       False      False        False              False  False
#
#      Letter Of Recommendation   CGPA  Research    COA
# 0                       False  False     False  False
# 1                       False  False     False  False
# ...

# %%
data.isnull().any()
# Out:
# Serial No.                  False
# GRE Score                   False
# TOEFL Score                 False
# University Rating           False
# SOP                         False
# Letter Of Recommendation    False
# CGPA                        False
# Research                    False
# COA                         False
# dtype: bool

# %% [markdown]
# # Descriptive Analysis

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#        Letter Of Recommendation        CGPA    Research         COA
# count                400.000000  400.000000  400.000000  400.000000
# mean                   3.452500    8.598925    0.547500    0.724350
# std                    0.898478    0.596317    0.498362    0.142609
# ...

# %%
data.mean()
# Out:
# Serial No.                  200.500000
# GRE Score                   316.807500
# TOEFL Score                 107.410000
# University Rating             3.087500
# SOP                           3.400000
# Letter Of Recommendation      3.452500
# CGPA                          8.598925
# Research                      0.547500
# COA                           0.724350
# dtype: float64

# %%
data.mode()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  \
# 0             1      312.0        110.0                3.0  3.5
# 1             2      324.0          NaN                NaN  4.0
# 2             3        NaN          NaN                NaN  NaN
# 3             4        NaN          NaN                NaN  NaN
# 4             5        NaN          NaN                NaN  NaN
# ..          ...        ...          ...                ...  ...
# 395         396        NaN          NaN                NaN  NaN
# 396         397        NaN          NaN                NaN  NaN
# 397         398        NaN          NaN                NaN  NaN
# 398         399        NaN          NaN                NaN  NaN
# 399         400        NaN          NaN                NaN  NaN
#
#      Letter Of Recommendation  CGPA  Research   COA
# 0                         3.0   8.0       1.0  0.64
# 1                         NaN   NaN       NaN   NaN
# ...

# %%
data.median()
# Out:
# Serial No.                  200.50
# GRE Score                   317.00
# TOEFL Score                 107.00
# University Rating             3.00
# SOP                           3.50
# Letter Of Recommendation      3.50
# CGPA                          8.61
# Research                      1.00
# COA                           0.73
# dtype: float64

# %% [markdown]
# # Visual Analysis

# %% [markdown]
# ### Uni Variate Analysis

# %%
sns.distplot(data['GRE Score'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='GRE Score', ylabel='Density'>

# %%
sns.distplot(data['TOEFL Score'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TOEFL Score', ylabel='Density'>

# %%
sns.distplot(data['University Rating'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='University Rating', ylabel='Density'>

# %%
sns.distplot(data['SOP'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SOP', ylabel='Density'>

# %%
sns.distplot(data['Letter Of Recommendation'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Letter Of Recommendation', ylabel='Density'>

# %%
sns.distplot(data['CGPA'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CGPA', ylabel='Density'>

# %%
sns.distplot(data['Research'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Research', ylabel='Density'>

# %%
sns.distplot(data['COA'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='COA', ylabel='Density'>

# %% [markdown]
# ### Bi Variate Analysis

# %%
sns.lineplot(data['GRE Score'], data['University Rating'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GRE Score', ylabel='University Rating'>

# %%
sns.lineplot(data['GRE Score'], data['CGPA'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GRE Score', ylabel='CGPA'>

# %%
sns.lineplot(data['University Rating'], data['CGPA'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='University Rating', ylabel='CGPA'>

# %%
sns.lineplot(data['CGPA'], data['COA'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CGPA', ylabel='COA'>

# %%
sns.lineplot(data['GRE Score'], data['COA'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GRE Score', ylabel='COA'>

# %%
sns.lineplot(data['GRE Score'], data['Letter Of Recommendation'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GRE Score', ylabel='Letter Of Recommendation'>

# %%
sns.lineplot(data['TOEFL Score'], data['CGPA'])
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOEFL Score', ylabel='CGPA'>

# %%
sns.pairplot(data=data,hue='Research',markers=["^","v"],palette='inferno')

# %%
data.corr()
# Out:
#                           Serial No.  GRE Score  TOEFL Score  \
# Serial No.                  1.000000  -0.097526    -0.147932
# GRE Score                  -0.097526   1.000000     0.835977
# TOEFL Score                -0.147932   0.835977     1.000000
# University Rating          -0.169948   0.668976     0.695590
# SOP                        -0.166932   0.612831     0.657981
# Letter Of Recommendation   -0.088221   0.557555     0.567721
# CGPA                       -0.045608   0.833060     0.828417
# Research                   -0.063138   0.580391     0.489858
# COA                         0.042336   0.802610     0.791594
#
#                           University Rating       SOP  \
# Serial No.                        -0.169948 -0.166932
# GRE Score                          0.668976  0.612831
# TOEFL Score                        0.695590  0.657981
# University Rating                  1.000000  0.734523
# SOP                                0.734523  1.000000
# ...

# %%
sns.heatmap(data.corr())
fig = plt.figure(figsize=(50,20))

# %%
category = ['GRE Score','TOEFL Score','University Rating','SOP','Letter Of Recommendation','CGPA','Research','COA']
color = ['yellowgreen','gold','lightskyblue','pink','red','purple','orange','gray']
start = True
for i in np.arange(4):
    fig = plt.figure(figsize=(14,8))
    plt.subplot2grid((4,2),(i,0))
    data[category[2*i]].hist(color=color[2*i],bins=10)
    plt.title(category[2*i])
    plt.subplot2grid((4,2),(i,1))
    data[category[2*i+1]].hist(color=color[2*i+1],bins=10)
    plt.title(category[2*i+1])
    
plt.subplots_adjust(hspace = 0.7, wspace = 0.2)
plt.show()

# %% [markdown]
# ## Split the data

# %%
#split the data

x = data[['GRE Score','TOEFL Score','University Rating','SOP','Letter Of Recommendation','CGPA','Research']]
y=data['COA']

# %%
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  Letter Of Recommendation  \
# 0          337          118                  4  4.5                       4.5
# 1          324          107                  4  4.0                       4.5
# 2          316          104                  3  3.0                       3.5
# 3          322          110                  3  3.5                       2.5
# 4          314          103                  2  2.0                       3.0
# ..         ...          ...                ...  ...                       ...
# 395        324          110                  3  3.5                       3.5
# 396        325          107                  3  3.0                       3.5
# 397        330          116                  4  5.0                       4.5
# 398        312          103                  3  3.5                       4.0
# 399        333          117                  4  5.0                       4.0
#
#      CGPA  Research
# ...

# %%
x = data[['GRE Score','TOEFL Score','University Rating','SOP','Letter Of Recommendation','CGPA','Research']].values
y=data['COA'].values

# %%
x
# Out:
# array([[337.  , 118.  ,   4.  , ...,   4.5 ,   9.65,   1.  ],
#        [324.  , 107.  ,   4.  , ...,   4.5 ,   8.87,   1.  ],
#        [316.  , 104.  ,   3.  , ...,   3.5 ,   8.  ,   1.  ],
#        ...,
#        [330.  , 116.  ,   4.  , ...,   4.5 ,   9.45,   1.  ],
#        [312.  , 103.  ,   3.  , ...,   4.  ,   8.78,   0.  ],
#        [333.  , 117.  ,   4.  , ...,   4.  ,   9.66,   1.  ]])

# %%
y
# Out:
# array([0.92, 0.76, 0.72, 0.8 , 0.65, 0.9 , 0.75, 0.68, 0.5 , 0.45, 0.52,
#        0.84, 0.78, 0.62, 0.61, 0.54, 0.66, 0.65, 0.63, 0.62, 0.64, 0.7 ,
#        0.94, 0.95, 0.97, 0.94, 0.76, 0.44, 0.46, 0.54, 0.65, 0.74, 0.91,
#        0.9 , 0.94, 0.88, 0.64, 0.58, 0.52, 0.48, 0.46, 0.49, 0.53, 0.87,
#        0.91, 0.88, 0.86, 0.89, 0.82, 0.78, 0.76, 0.56, 0.78, 0.72, 0.7 ,
#        0.64, 0.64, 0.46, 0.36, 0.42, 0.48, 0.47, 0.54, 0.56, 0.52, 0.55,
#        0.61, 0.57, 0.68, 0.78, 0.94, 0.96, 0.93, 0.84, 0.74, 0.72, 0.74,
#        0.64, 0.44, 0.46, 0.5 , 0.96, 0.92, 0.92, 0.94, 0.76, 0.72, 0.66,
#        0.64, 0.74, 0.64, 0.38, 0.34, 0.44, 0.36, 0.42, 0.48, 0.86, 0.9 ,
#        0.79, 0.71, 0.64, 0.62, 0.57, 0.74, 0.69, 0.87, 0.91, 0.93, 0.68,
#        0.61, 0.69, 0.62, 0.72, 0.59, 0.66, 0.56, 0.45, 0.47, 0.71, 0.94,
#        0.94, 0.57, 0.61, 0.57, 0.64, 0.85, 0.78, 0.84, 0.92, 0.96, 0.77,
#        0.71, 0.79, 0.89, 0.82, 0.76, 0.71, 0.8 , 0.78, 0.84, 0.9 , 0.92,
# ...

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
sc = MinMaxScaler()
x_scaled = sc.fit_transform(x)

# %%
x_scaled
# Out:
# array([[0.94      , 0.92857143, 0.75      , ..., 0.875     , 0.91346154,
#         1.        ],
#        [0.68      , 0.53571429, 0.75      , ..., 0.875     , 0.66346154,
#         1.        ],
#        [0.52      , 0.42857143, 0.5       , ..., 0.625     , 0.38461538,
#         1.        ],
#        ...,
#        [0.8       , 0.85714286, 0.75      , ..., 0.875     , 0.84935897,
#         1.        ],
#        [0.44      , 0.39285714, 0.5       , ..., 0.75      , 0.63461538,
#         0.        ],
#        [0.86      , 0.89285714, 0.75      , ..., 0.75      , 0.91666667,
#         1.        ]])

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=101)

# %%
x_train
# Out:
# array([[329.  , 114.  ,   5.  , ...,   5.  ,   9.19,   1.  ],
#        [327.  , 113.  ,   4.  , ...,   5.  ,   9.14,   0.  ],
#        [317.  , 107.  ,   3.  , ...,   3.  ,   8.68,   1.  ],
#        ...,
#        [332.  , 118.  ,   5.  , ...,   5.  ,   9.47,   1.  ],
#        [327.  , 111.  ,   4.  , ...,   4.5 ,   9.  ,   1.  ],
#        [325.  , 110.  ,   4.  , ...,   4.  ,   8.67,   1.  ]])

# %%
y_train
# Out:
# array([0.86, 0.83, 0.84, 0.87, 0.49, 0.74, 0.9 , 0.91, 0.71, 0.84, 0.94,
#        0.7 , 0.9 , 0.64, 0.72, 0.47, 0.44, 0.57, 0.74, 0.71, 0.48, 0.82,
#        0.69, 0.71, 0.89, 0.78, 0.82, 0.8 , 0.61, 0.76, 0.71, 0.54, 0.79,
#        0.57, 0.66, 0.9 , 0.95, 0.74, 0.96, 0.58, 0.63, 0.79, 0.97, 0.66,
#        0.64, 0.71, 0.73, 0.74, 0.68, 0.67, 0.79, 0.82, 0.56, 0.92, 0.77,
#        0.93, 0.49, 0.7 , 0.91, 0.71, 0.83, 0.93, 0.84, 0.64, 0.62, 0.76,
#        0.7 , 0.52, 0.82, 0.67, 0.86, 0.49, 0.66, 0.73, 0.88, 0.79, 0.58,
#        0.94, 0.76, 0.87, 0.62, 0.78, 0.34, 0.64, 0.93, 0.76, 0.61, 0.81,
#        0.76, 0.79, 0.67, 0.64, 0.77, 0.94, 0.84, 0.62, 0.47, 0.61, 0.88,
#        0.67, 0.7 , 0.65, 0.64, 0.93, 0.46, 0.75, 0.64, 0.73, 0.67, 0.68,
#        0.96, 0.85, 0.78, 0.79, 0.96, 0.62, 0.94, 0.94, 0.53, 0.84, 0.75,
#        0.44, 0.42, 0.64, 0.95, 0.76, 0.5 , 0.72, 0.79, 0.77, 0.94, 0.81,
#        0.7 , 0.69, 0.61, 0.72, 0.76, 0.94, 0.89, 0.66, 0.57, 0.48, 0.9 ,
# ...

# %%
x_test
# Out:
# array([[304.  , 105.  ,   1.  ,   3.  ,   1.5 ,   7.5 ,   0.  ],
#        [307.  , 105.  ,   2.  ,   2.  ,   3.5 ,   8.1 ,   0.  ],
#        [306.  , 105.  ,   2.  ,   2.5 ,   3.  ,   8.22,   1.  ],
#        [305.  , 107.  ,   2.  ,   2.5 ,   2.5 ,   8.42,   0.  ],
#        [307.  , 107.  ,   2.  ,   3.  ,   3.5 ,   8.52,   1.  ],
#        [315.  , 110.  ,   2.  ,   3.5 ,   3.  ,   8.46,   1.  ],
#        [323.  , 112.  ,   5.  ,   4.  ,   4.5 ,   8.78,   0.  ],
#        [296.  ,  99.  ,   2.  ,   3.  ,   3.5 ,   7.28,   0.  ],
#        [324.  , 112.  ,   5.  ,   5.  ,   5.  ,   9.08,   1.  ],
#        [322.  , 110.  ,   5.  ,   4.5 ,   4.  ,   8.97,   0.  ],
#        [324.  , 113.  ,   4.  ,   4.5 ,   4.  ,   8.79,   0.  ],
#        [312.  , 107.  ,   3.  ,   3.  ,   3.  ,   8.46,   1.  ],
#        [334.  , 117.  ,   5.  ,   4.  ,   4.5 ,   9.07,   1.  ],
#        [340.  , 120.  ,   4.  ,   4.5 ,   4.  ,   9.92,   1.  ],
# ...

# %%
y_test
# Out:
# array([0.52, 0.53, 0.72, 0.71, 0.78, 0.72, 0.79, 0.47, 0.88, 0.78, 0.76,
#        0.75, 0.89, 0.97, 0.39, 0.75, 0.65, 0.7 , 0.51, 0.62, 0.58, 0.67,
#        0.78, 0.64, 0.57, 0.74, 0.78, 0.74, 0.57, 0.79, 0.71, 0.59, 0.5 ,
#        0.93, 0.6 , 0.57, 0.71, 0.58, 0.71, 0.77, 0.68, 0.87, 0.9 , 0.74,
#        0.75, 0.96, 0.65, 0.77, 0.56, 0.72, 0.63, 0.93, 0.85, 0.54, 0.73,
#        0.7 , 0.72, 0.56, 0.65, 0.38, 0.49, 0.74, 0.64, 0.38, 0.72, 0.64,
#        0.76, 0.71, 0.45, 0.68, 0.53, 0.55, 0.82, 0.63, 0.54, 0.96, 0.62,
#        0.9 , 0.62, 0.64, 0.65, 0.8 , 0.46, 0.91, 0.89, 0.73, 0.72, 0.73,
#        0.8 , 0.7 , 0.72, 0.65, 0.78, 0.9 , 0.59, 0.65, 0.64, 0.76, 0.69,
#        0.52, 0.48, 0.42, 0.68, 0.45, 0.67, 0.78, 0.47, 0.84, 0.93, 0.85,
#        0.66, 0.7 , 0.64, 0.8 , 0.97, 0.71, 0.72, 0.73, 0.83, 0.73])

# %%
y_train=(y_train>0.5)
y_train
# Out:
# array([ True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False, False,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
y_test=(y_test>0.5)
y_test
# Out:
# array([ True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False, False,  True,  True,
#        False,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False,  True, False,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
from sklearn.linear_model import LogisticRegression
cls =LogisticRegression(random_state=0)

lr=cls.fit(x_train, y_train)
# Out:
# C:\Users\BALA\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
#libraries to train Neural network
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense,Activation,Dropout
from tensorflow.keras.optimizers import Adam

# %%
# Initialize the model
model=keras.Sequential()

# Add input Layer
model.add(Dense(7, activation ='relu',input_dim=7))

# Add hidden Layers
model.add(Dense(7,activation='relu'))

# Add output Layer
model.add(Dense(1,activation='linear'))

model.summary ()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 7)                 56
#
#  dense_1 (Dense)             (None, 7)                 56
#
#  dense_2 (Dense)             (None, 1)                 8
#
# ...
# Total params: 120
# Trainable params: 120
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile()

# %%
model.compile(loss= 'binary_crossentropy',optimizer = 'adam',metrics =['accuracy'])

# %%
model.fit(x_train, y_train, batch_size = 20, epochs = 100)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 12s 16ms/step - loss: 1.2526 - accuracy: 0.9179
# Epoch 2/100
# 14/14 [==============================] - 0s 14ms/step - loss: 1.2526 - accuracy: 0.9179
# Epoch 3/100
# 14/14 [==============================] - 0s 11ms/step - loss: 1.2526 - accuracy: 0.9179
# Epoch 4/100
# 14/14 [==============================] - 0s 12ms/step - loss: 1.2526 - accuracy: 0.9179
# Epoch 5/100
# 14/14 [==============================] - 0s 15ms/step - loss: 1.2526 - accuracy: 0.9179
# Epoch 6/100
# 14/14 [==============================] - 0s 11ms/step - loss: 1.2526 - accuracy: 0.9179
# Epoch 7/100
# 14/14 [==============================] - 0s 12ms/step - loss: 1.2526 - accuracy: 0.9179
# Epoch 8/100
# 14/14 [==============================] - 0s 13ms/step - loss: 1.2526 - accuracy: 0.9179
# Epoch 9/100
# 14/14 [==============================] - 0s 15ms/step - loss: 1.2526 - accuracy: 0.9179
# Epoch 10/100
# ...

# %%
from sklearn.metrics import accuracy_score


#Make predictions on the training data
train_predictions=model.predict(x_train)

print(train_predictions)
# Out:
# 9/9 [==============================] - 1s 14ms/step
# [[57.840965]
#  [57.737644]
#  [55.66975 ]
#  [57.86645 ]
#  [55.386314]
#  [57.61436 ]
#  [57.75156 ]
#  [59.279774]
#  [55.097603]
#  [57.03265 ]
#  [58.274155]
#  [54.922478]
#  [57.84312 ]
#  [55.527176]
#  [55.222298]
#  [50.90909 ]
#  [52.025196]
#  [53.24118 ]
#  [56.056538]
#  [55.623375]
#  [54.65682 ]
#  [55.72303 ]
#  [52.500053]
#  [56.036194]
#  [58.735783]
#  [57.21794 ]
#  [57.73766 ]
#  [55.50008 ]
#  [53.841526]
#  [54.710148]
#  [55.950382]
#  [54.83331 ]
#  [55.22374 ]
#  [54.932873]
#  [54.3617  ]
#  [60.066433]
#  [59.145058]
#  [55.489666]
#  [58.46721 ]
#  [52.920525]
#  [55.783005]
#  [56.88723 ]
#  [59.772842]
#  [53.590366]
#  [54.64107 ]
#  [58.043716]
#  [54.36819 ]
#  [56.313847]
#  [52.642887]
#  [56.11969 ]
#  [57.194935]
#  [55.11913 ]
#  [53.47607 ]
#  [56.547073]
#  [54.259407]
#  [58.28588 ]
#  [51.969112]
#  [56.223236]
#  [56.512123]
#  [53.516212]
#  [57.112522]
#  [58.690113]
#  [55.199226]
# ...

# %%
#Get the training accuracy
train_acc=model.evaluate(x_train,y_train,verbose=0)[1]

print(train_acc)
# Out:
# 0.9178571701049805

# %%
#Get the test aacuracy
test_acc=model.evaluate(x_test,y_test,verbose=0)[1]

print(test_acc)
# Out:
# 0.8999999761581421

# %%
pred=model.predict(x_test)
pred=(pred>0.5)
pred
# Out:
# 4/4 [==============================] - 0s 17ms/step
# array([[ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
# ...

# %%
from sklearn.metrics import accuracy_score,recall_score,roc_auc_score,confusion_matrix
print("\nAccuracy score: %f" %(accuracy_score(y_test,y_pred)*100))
print("Recall score : %f" %(recall_score(y_test,y_pred)*100))
print("ROC score : %f\n" %(roc_auc_score(y_test,y_pred)*100))
print(confusion_matrix(y_test,y_pred))
# Out:
# Accuracy score: 85.833333
# Recall score : 95.370370
# ROC score : 47.685185
#
# [[  0  12]
#  [  5 103]]

# %%
from sklearn.metrics import classification_report,accuracy_score, recall_score, roc_auc_score, confusion_matrix

# %%
print(classification_report(y_pred ,pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00         5
#         True       0.96      1.00      0.98       115
#
#     accuracy                           0.96       120
#    macro avg       0.48      0.50      0.49       120
# weighted avg       0.92      0.96      0.94       120
# C:\Users\BALA\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\BALA\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print(classification_report(y_test ,pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        12
#         True       0.90      1.00      0.95       108
#
#     accuracy                           0.90       120
#    macro avg       0.45      0.50      0.47       120
# weighted avg       0.81      0.90      0.85       120
# C:\Users\BALA\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\BALA\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
model.save('model.h5')
